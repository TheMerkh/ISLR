# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

df = pd.read_csv("Weekly.csv")

df
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5    Volume  Today Direction
# 0     1990  0.816  1.572 -3.936 -0.229 -3.484  0.154976 -0.270      Down
# 1     1990 -0.270  0.816  1.572 -3.936 -0.229  0.148574 -2.576      Down
# 2     1990 -2.576 -0.270  0.816  1.572 -3.936  0.159837  3.514        Up
# 3     1990  3.514 -2.576 -0.270  0.816  1.572  0.161630  0.712        Up
# 4     1990  0.712  3.514 -2.576 -0.270  0.816  0.153728  1.178        Up
# ...    ...    ...    ...    ...    ...    ...       ...    ...       ...
# 1084  2010 -0.861  0.043 -2.173  3.599  0.015  3.205160  2.969        Up
# 1085  2010  2.969 -0.861  0.043 -2.173  3.599  4.242568  1.281        Up
# 1086  2010  1.281  2.969 -0.861  0.043 -2.173  4.835082  0.283        Up
# 1087  2010  0.283  1.281  2.969 -0.861  0.043  4.454044  1.034        Up
# 1088  2010  1.034  0.283  1.281  2.969 -0.861  2.707105  0.069        Up
#
# [1089 rows x 9 columns]

# %% [markdown]
# Q: Fit a logistic regression model that predicts Direction using Lag1 and Lag2.

# %%
X = df[["Lag1", "Lag2"]]
y = df["Direction"]
X = sm.add_constant(X)
y = y.map({"Up": 1, "Down": 0})

log_dir = sm.Logit(y, X).fit()

print(log_dir.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.683297
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:              Direction   No. Observations:                 1089
# Model:                          Logit   Df Residuals:                     1086
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 23 Aug 2023   Pseudo R-squ.:                0.005335
# Time:                        19:39:11   Log-Likelihood:                -744.11
# converged:                       True   LL-Null:                       -748.10
# Covariance Type:            nonrobust   LLR p-value:                   0.01848
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2212      0.061      3.599      0.000       0.101       0.342
# ...

# %% [markdown]
# Q: Fit a logistic regression model that predicts Direction using Lag1 and Lag2 using all but the first observation.

# %%
df1 = df.iloc[1:]

X1 = df1[["Lag1", "Lag2"]]
y1 = df1["Direction"]
X1 = sm.add_constant(X1)
y1 = y1.map({"Up": 0, "Down": 1})

log_dir_1 = sm.Logit(y1, X1).fit()

# Muestra un resumen del modelo
print(log_dir_1.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.683147
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:              Direction   No. Observations:                 1088
# Model:                          Logit   Df Residuals:                     1085
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 23 Aug 2023   Pseudo R-squ.:                0.005387
# Time:                        20:10:53   Log-Likelihood:                -743.26
# converged:                       True   LL-Null:                       -747.29
# Covariance Type:            nonrobust   LLR p-value:                   0.01785
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2232      0.061     -3.630      0.000      -0.344      -0.103
# ...

# %% [markdown]
# Q: Use the model from (b) to predict the direction of the first observation. You can do this by predicting that the first observation will go up if P(Direction=Up|Lag1,Lag2)>0.5
# . Was this observation correctly classified?

# %%
prediction = "Up" if log_dir_1.predict(X)[0] > 0.5 else "Down"

print(prediction)
print(df.iloc[0, 8])
# Out:
# Down
# Down

# %% [markdown]
# Q: Write a for loop from i = 1 to i = n
# , where n
#  is the number of observations in the data set, that performs each of the following steps:
#
# i. Fit a logistic regression model using all but the ith observation to predict Direction using Lag1 and Lag2.
#
# ii. Compute the posterior probability of the market moving up for the ith observation.
#
# iii. Use the posterior probability for the ith observation in order to predict whether or not the market moves up.
#
# iv. Determine whether or not an error was made in predicting the direction for the ith observation. If an error was made, then indicate this as a 1, and otherwise indicate it as a 0.

# %%
errors = []

for i in range(len(df)):
    
    temp_data = df.drop(index=i)
    
    X_temp = temp_data[["Lag1", "Lag2"]]
    y_temp = temp_data["Direction"]
    y_temp = y_temp.map({"Up": 1, "Down": 0})
    log_dir = sm.Logit(y_temp, sm.add_constant(X_temp)).fit()
    
    
    prediction = log_dir.predict(X.iloc[i])

    error = int((prediction > 0.5) != (df.iloc[i, 0] == "Up"))
    errors.append(error)

print(errors[:10])
# Out:
# Optimization terminated successfully.
#          Current function value: 0.683147
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683149
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683416
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683253
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683454
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683181
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683432
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683335
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683402
#          Iterations 4
# ...

# %% [markdown]
# Q: Take the average of the n
#  numbers obtained in (d) iv. in order to obtain the LOOCV estimate for the test error. Comment on the results.

# %%
np.mean(errors)
# Out:
# 0.9320477502295684

# %%
df["Direction"].value_counts(normalize=True)
# Out:
# Up      0.555556
# Down    0.444444
# Name: Direction, dtype: float64
